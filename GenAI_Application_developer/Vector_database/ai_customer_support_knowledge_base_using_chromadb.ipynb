# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragdixit22081993/my_practice_aiml/blob/main/GenAI_Application_developer/Vector_database/ai_customer_support_knowledge_base_using_chromadb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 68.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 109.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# Install first:
# pip install chromadb

import chromadb

# 1. Create persistent ChromaDB client
client = chromadb.PersistentClient(path="./customer_support_db")

# 2. Create / get collection
collection = client.get_or_create_collection(name="support_knowledge_base")

# %%
# 3. Sample support documents
documents = [
    "If the router red light is blinking, restart the router and check the fiber cable.",
    "To reset your password, click Forgot Password on the login page.",
    "Warranty replacement is available within one year of purchase.",
    "If internet is slow, check Wi-Fi signal strength and restart the modem.",
    "For billing issues, contact accounts support with your invoice number."
]

ids = [
    "doc1",
    "doc2",
    "doc3",
    "doc4",
    "doc5"
]

# 4. Add documents to ChromaDB
collection.add(
    documents=documents,
    ids=ids
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:02<00:00, 40.5MiB/s]

# %%
# 5. Customer question
question = "My router has a blinking red light. What should I do?"

# 6. Retrieve relevant documents
results = collection.query(
    query_texts=[question],
    n_results=2
)

# %%
# 7. Print retrieved knowledge
print("\nCustomer Question:")
print(question)

print("\nRelevant Knowledge Retrieved from ChromaDB:")
for doc in results["documents"][0]:
    print("-", doc)

# 8. Simple final answer without LLM
print("\nFinal Answer:")
print(
    "A blinking red router light usually means there may be a connection issue. "
    "Please restart the router and check whether the fiber cable is properly connected. "
    "If the problem continues, contact technical support."
)
# Out:
# Customer Question:
# My router has a blinking red light. What should I do?
#
# Relevant Knowledge Retrieved from ChromaDB:
# - If the router red light is blinking, restart the router and check the fiber cable.
# - If internet is slow, check Wi-Fi signal strength and restart the modem.
#
# Final Answer:
# A blinking red router light usually means there may be a connection issue. Please restart the router and check whether the fiber cable is properly connected. If the problem continues, contact technical support.
