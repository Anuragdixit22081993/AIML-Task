# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragdixit22081993/my_practice_aiml/blob/main/gemini_describe_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai pillow requests

# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)

# %%
from google import genai
from google.genai import types
from PIL import Image
from io import BytesIO
import requests

image_url = "https://goo.gle/instrument-img"

headers = {
    "User-Agent": "Mozilla/5.0"
}

r = requests.get(image_url, headers=headers, timeout=20)
r.raise_for_status()

# Open image and convert to clean JPEG
img = Image.open(BytesIO(r.content)).convert("RGB")

buffer = BytesIO()
img.save(buffer, format="JPEG")
image_bytes = buffer.getvalue()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        types.Part.from_bytes(
            data=image_bytes,
            mime_type="image/jpeg"
        ),
        "Explain this image in simple English."
    ]
)

print(response.text)
# Out:
# This image shows a large, elaborate **organ console**, which is the control center where an organist sits to play a pipe organ or a sophisticated digital organ.
#
# Here's a breakdown of what you see:
#
# *   **Wood Construction:** The entire console is made of polished light brown wood, likely oak, giving it a classic and sturdy appearance.
# *   **Keyboards (Manuals):** In the center, there are five rows of black and white keys, similar to a piano, but typically shorter. These are played with the organist's hands.
# *   **Stop Controls:** On the left and right sides, and above the top keyboard, there are many rows of small, rectangular switches (some white, some black). These are called "stops" and are used to select different sounds (like flutes, trumpets, strings) and to combine them to create various musical textures.
# *   **Pedalboard:** At the very bottom, there's a fan-shaped arrangement of long wooden pedals. These are played with the organist's feet to produce bass notes.
# ...
